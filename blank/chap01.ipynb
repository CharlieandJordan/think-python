# %% [markdown]
# <a href="https://colab.research.google.com/github/CharlieandJordan/think-python/blob/main/blank/chap01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dagger = Item({'name': "Dagger of Oblivion", 'description': "A stabby thing"})
dagger.name
# Out:
# 'Dagger of Oblivion'

# %%
## Base Race Class
class Race():
  def __init__(self, d = {
      'stats_modifier': [1, 1, 1, 1, 1, 1],
      'innate_abilities': [],
      'size': 'medium'}):
    self.stats_modifiers = d['stats_modifier']

  def get_mod(self, stat):
    stats = ['str', 'dex', 'con', 'int', 'wis', 'cha']
    if type(stat) == int:
      return self.stats_modifiers[stat]
    elif type(stat) == str:
      return self.stats_modifiers[stats.index(stat)]
    else:
      None


################################



## Base Character Class
class Character():
  """ Base character class """


  def __init__(self, d = {
      'name': None,
      'race': 'Human',
      'class': 'Warrior',
      'level': 1,
      'stats': [0,0,0,0,0,0]}):
    self.name = d['name']
    self.stats = d['stats']
    self.race = d['race']
    self.level = d['level']
    self.cclass = d['class']

  def __str__(self):
    self.pcs()


  def get_stat(self, stat):
    stats = ['str', 'dex', 'con', 'int', 'wis', 'cha']
    if type(stat) == int:
      return self.stats[stat]
    elif type(stat) == str:
      return self.stats[stats.index(stat)]
    else:
      None


  def computed_stat(self, stat):
    return int(self.get_stat(stat) * races[self.race].get_mod(stat))

  def pcs(self):
    print(f'Character sheet for {self.name}\n')
    print(f'Race: {self.race}')
    print(f'Class: {self.cclass}')
    print(f'Level: {self.level}')
    print(f'Stats:')
    print(f'Strength:     {self.get_stat('str'):>3}    Intelligence: {self.get_stat('int'):>3}')
    print(f'Dexterity:    {self.get_stat('dex'):>3}    Wisdom:       {self.get_stat('wis'):>3}')
    print(f'Constitution: {self.get_stat('con'):>3}    Charisma:     {self.get_stat('cha'):>3}')
    print('\n\n')


################################


## Base Item Class
#create an Item class
class Item():
  def __init__(self, d = {
      'name':'Dagger of Oblivian',
      'description': 'a stabby thingy'}):
    self.name = d['name']
    self.description = d['description']
# the class needs an init function name and description
# use the Race() class as a starter, edit as necessary


dagger = Item({'name': "Dagger of Oblivion", 'description': "A stabby thing"})
dagger.name
################################


## Creates Race Instances
#from character import Character
#from race import Race


races = {}
races['Human'] = Race()
races['Dwarf'] = Race({'stats_modifier': [1.1, 1, 1.3, .9, 1, 10], 'size': 'medium_small', 'innate_abilities': ['infravision']})
races['Grey Elf'] = Race({'stats_modifier': [.7, 1.2, .8, 1.1, 1, 1.1], 'size': 'medium_small', 'innate_abilities': ['infravision', 'outdoor_sneak']})
races['Ogre'] = Race({'stats_modifier': [1.5, .8, 1.5, .5, .75, .75], 'size': 'large' ,'innate_abilities': ['doorbash']})

## Create a moted Instance
characters = {}
characters['Moted'] = Character({
    'name': "Moted",
    'race': 'Dwarf',
    'class': 'Shaman',
    'level': 24,
    "stats": [88, 80, 80, 80, 80, 80]})
characters['Aleolas'] = Character({
    'name': "Aleolas",
    'race': 'Grey Elf',
    'class': 'Ranger',
    'level': 50,
    "stats": [100, 80, 100, 80, 80, 80]})
characters['Illilel'] = Character({
    'name': "Illilel",
    'race': "Grey Elf",
    'class': "Bard",
    'level': 50,
    'stats': [100, 100, 100, 72, 54, 100]
})

def character_list(char_list):
  print(f'{"Name":<15} {"Race":<12} {"Class":<10} {"Level":>2}')
  print("_" * 45, end="\n\n")

  for (_, char) in char_list.items():
    print(f'{char.name:<15} {char.race:<12} {char.cclass:<10} {char.level:>5}')

character_list(characters)
# Out:
# Name            Race         Class      Level
# _____________________________________________
#
# Moted           Dwarf        Shaman        24
# Aleolas         Grey Elf     Ranger        50
# Illilel         Grey Elf     Bard          50

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + str(local))
    return filename

download('https://github.com/AllenDowney/ThinkPython/raw/v3/thinkpython.py');
download('https://github.com/AllenDowney/ThinkPython/raw/v3/diagram.py');

import thinkpython
# Out:
# Downloaded thinkpython.py
# Downloaded diagram.py
